# %% [markdown]
# NRC sentiment analysis for Amazon laptop lexicons based on customer reviews

# %%
def get_nrc_data():
    nrc_bigram = "/Users/zhen/Desktop/Amazon-laptops-electronics-reviews-AFFLEX-NEGLEX-bigrams.txt"
    nrc_unigram = "/Users/zhen/Desktop/Amazon-laptops-electronics-reviews-AFFLEX-NEGLEX-unigrams.txt"
    count=0
    emotion_dict=dict()
    with open (nrc_bigram,'r') as b:
        all_lines = list()
        for line in b:
            line = line.strip().split('\t')
            if int(line[2]) == 1:
                if emotion_dict.get(line[0]):
                    emotion_dict[line[0]].append(line[1])
                else:
                    emotion_dict[line[0]] = [line[1]]
                    
    with open (nrc_unigram,'r') as u:
        all_lines = list()
        for line in u:
            line = line.strip().split('\t')
            if int(line[2]) == 1:
                if emotion_dict.get(line[0]):
                    emotion_dict[line[0]].append(line[1])
                else:
                    emotion_dict[line[0]] = [line[1]]
    
    return emotion_dict

# %%
get_nrc_data()
# Out:
# {'worst ever': ['-2.201'],
#  'star only': ['-2.201'],
#  'or email_NEG': ['-2.201'],
#  'outer edges': ['-2.201'],
#  'night it': ['-2.201'],
#  'garmin emap': ['-2.201'],
#  'same behavior': ['-2.201'],
#  'in broken': ['-2.201'],
#  'been_NEG released_NEG': ['-2.201'],
#  "companion 5's": ['-2.201'],
#  'bad purchase': ['-2.201'],
#  "it's worse": ['-2.201'],
#  'even_NEG plug_NEG': ['-2.201'],
#  'junk !!': ['-2.201'],
#  ', shoddy': ['-2.201'],
#  'cord started': ['-2.201'],
#  ', attempting': ['-2.201'],
#  'finally recognized': ['-2.201'],
#  'poor rating': ['-2.201'],
#  'hp as': ['-2.201'],
#  'or allow_NEG': ['-2.201'],
#  'admits that': ['-2.201'],
#  'wired side': ['-2.201'],
#  'be_NEG formatted_NEG': ['-2.201'],
#  'warranty ?': ['-2.201'],
#  'unit died': ['-2.201'],
#  'mad that': ['-2.201'],
#  'poorly engineered': ['-2.201'],
#  'to expectations_NEG': ['-2.201'],
#  'to lenovo': ['-2.201'],
#  'one moment': ['-2.201'],
#  'yesterday the': ['-2.201'],
#  'explain_NEG why_NEG': ['-2.201'],
#  'keyboard problems': ['-2.201'],
#  'your cash_NEG': ['-2.201'],
#  'card caused': ['-2.201'],
#  'a widespread': ['-2.201'],
#  'worse over': ['-2.201'],
#  'remains .': ['-2.201'],
#  'great doing': ['-2.201'],
#  'bad router': ['-2.201'],
#  'excited at': ['-2.201'],
#  'was intermittent': ['-2.201'],
#  'tracks ;': ['-2.201'],
#  'working today': ['-2.201'],
#  '2 different_NEG': ['-2.201'],
#  'hear this': ['-2.201'],
#  'it scanned': ['-2.201'],
#  'slow system': ['-2.201'],
#  'no drive_NEG': ['-2.201'],
#  'screen died': ['-2.201'],
#  'recovery service': ['-2.201'],
#  'answer_NEG from': ['-2.201'],
#  'keep having': ['-2.201'],
#  'freeagent drive': ['-2.201'],
#  'ever purchase': ['-2.201'],
#  'plastic fan': ['-2.201'],
#  '; bad': ['-2.201'],
#  'only_NEG would_NEG': ['-2.201'],
#  'she could_NEG': ['-2.201'],
#  'rep to': ['-2.201'],
#  'just junk': ['-2.201'],
#  'the parameters': ['-2.201'],
#  '! hp': ['-2.201'],
#  'disappointment and': ['-2.201'],
#  'told_NEG them': ['-2.201'],
#  'replace these': ['-2.201'],
#  'connection goes': ['-2.201'],
#  'suggested_NEG i': ['-2.201'],
#  'took as': ['-2.201'],
#  'hp says': ['-2.201'],
#  'blades on': ['-2.201'],
#  'luck than': ['-2.201'],
#  'it crapped': ['-2.201'],
#  'i argued': ['-2.201'],
#  'it freaks': ['-2.201'],
#  'and badly': ['-2.201'],
#  'overrated .': ['-2.201'],
#  'got jammed': ['-2.201'],
#  'the packets': ['-2.201'],
#  'support offered': ['-2.201'],
#  'stating "': ['-2.201'],
#  'to re-start': ['-2.201'],
#  'technician to': ['-2.201'],
#  'file a': ['-2.201'],
#  'tried replacing': ['-2.201'],
#  'at targus': ['-2.201'],
#  'connection_NEG so': ['-2.201'],
#  'minutes trying': ['-2.201'],
#  'even_NEG let_NEG': ['-2.201'],
#  'the offer': ['-2.201'],
#  'internal g': ['-2.201'],
#  'mine died': ['-2.201'],
#  'buy_NEG !!': ['-2.201'],
#  'started turning': ['-2.201'],
#  'any circumstances_NEG': ['-2.201'],
#  'heard_NEG back_NEG': ['-2.201'],
#  'recessed into': ['-2.201'],
#  'have followed': ['-2.201'],
#  'stereo component': ['-2.201'],
#  'desperately need': ['-2.201'],
#  '): you': ['-2.201'],
#  ') slow': ['-2.201'],
#  'oem adapter': ['-2.201'],
#  'and calling': ['-2.201'],
#  'times an': ['-2.201'],
#  'again_NEG due_NEG': ['-2.201'],
#  'river road': ['-2.201'],
#  'dell adapter': ['-2.201'],
#  'work_NEG either': ['-2.201'],
#  'rebooting_NEG .': ['-2.201'],
#  '1 support': ['-2.201'],
#  'constantly loses': ['-2.201'],
#  'was outside': ['-2.201'],
#  'connector did': ['-2.201'],
#  'senior tech': ['-2.201'],
#  'my defective': ['-2.201'],
#  "software won't": ['-2.201'],
#  'my co-worker': ['-2.201'],
#  'had defective': ['-2.201'],
#  'and touched': ['-2.201'],
#  'and reboots': ['-2.201'],
#  'another vga': ['-2.201'],
#  ': tried': ['-2.201'],
#  'a dissapointment': ['-2.201'],
#  'fate .': ['-2.201'],
#  'got nowhere': ['-2.201'],
#  'this poor': ['-2.201'],
#  'and disappointing': ['-2.201'],
#  'worse !': ['-2.201'],
#  'warranty_NEG period_NEG': ['-2.201'],
#  'the instrument': ['-2.201'],
#  'the expectation': ['-2.201'],
#  'had same': ['-2.201'],
#  'final straw': ['-2.201'],
#  'my worst': ['-2.201'],
#  'holding ,': ['-2.201'],
#  'up according': ['-2.201'],
#  'actual problem': ['-2.201'],
#  'is responsible': ['-2.201'],
#  'any repair': ['-2.201'],
#  'reseller .': ['-2.201'],
#  'the warrenty': ['-2.201'],
#  'must pay': ['-2.201'],
#  'netgear technical': ['-2.201'],
#  'description )': ['-2.201'],
#  'repeatedly to': ['-2.201'],
#  'd-link would': ['-2.201'],
#  'extremely flimsy': ['-2.201'],
#  'same steps': ['-2.201'],
#  'the reply': ['-2.201'],
#  'the poorest': ['-2.201'],
#  'repeated attempts': ['-2.201'],
#  'never responded_NEG': ['-2.201'],
#  'hp needs': ['-2.201'],
#  'mio 310x': ['-2.201'],
#  'no joy_NEG': ['-2.201'],
#  're-stocking fee': ['-2.201'],
#  'right fan': ['-2.201'],
#  'as useless': ['-2.201'],
#  'money wasted': ['-2.201'],
#  'he could_NEG': ['-2.201'],
#  'promised that': ['-2.201'],
#  'mediocre at': ['-2.201'],
#  'devices back': ['-2.201'],
#  'wireless icon': ['-2.201'],
#  'not manufactured_NEG': ['-2.201'],
#  'unfortunately after': ['-2.201'],
#  'clear_NEG at': ['-2.201'],
#  '>> |': ['-2.201'],
#  'thing died': ['-2.201'],
#  'just freezes': ['-2.201'],
#  'until ...': ['-2.201'],
#  'in fixing_NEG': ['-2.201'],
#  'ports stopped': ['-2.201'],
#  'days have': ['-2.201'],
#  'effective_NEG at': ['-2.201'],
#  'signal_NEG "': ['-2.201'],
#  'not lay_NEG': ['-2.201'],
#  'back twice': ['-2.201'],
#  'work_NEG half_NEG': ['-2.201'],
#  'would resolve': ['-2.201'],
#  'extreme "': ['-2.201'],
#  'secondary adapter': ['-2.201'],
#  'sheet metal': ['-2.201'],
#  'protector "': ['-2.201'],
#  'warning me': ['-2.201'],
#  'worst piece': ['-2.201'],
#  'a junk': ['-2.201'],
#  'problems disappeared': ['-2.201'],
#  'usb_NEG 2': ['-2.201'],
#  'stops for': ['-2.201'],
#  'am awaiting': ['-2.201'],
#  'good_NEG review_NEG': ['-2.201'],
#  'my tomtom': ['-2.201'],
#  'the cd-rom_NEG': ['-2.201'],
#  'better brand': ['-2.201'],
#  'to kodak': ['-2.201'],
#  'atrocious .': ['-2.201'],
#  "computer_NEG doesn't": ['-2.201'],
#  'broadcom card': ['-2.201'],
#  'worthless !': ['-2.201'],
#  'solution "': ['-2.201'],
#  'finding_NEG out': ['-2.201'],
#  'connection all': ['-2.201'],
#  'even_NEG boot_NEG': ['-2.201'],
#  'fired the': ['-2.201'],
#  '( per': ['-2.201'],
#  'keyboards were': ['-2.201'],
#  'marble wheel': ['-2.201'],
#  'months_NEG later_NEG': ['-2.201'],
#  'a horribly': ['-2.201'],
#  'is flaky': ['-2.201'],
#  'better card': ['-2.201'],
#  'rip-off .': ['-2.201'],
#  'few major': ['-2.201'],
#  'thought perhaps': ['-2.201'],
#  'lines across': ['-2.201'],
#  'router_NEG as': ['-2.201'],
#  'sub par': ['-2.201'],
#  'the dv2000': ['-2.201'],
#  '. lame': ['-2.201'],
#  "& i'm": ['-2.201'],
#  'logitech v470': ['-2.201'],
#  'personnel .': ['-2.201'],
#  'the aluratek': ['-2.201'],
#  'saying_NEG the': ['-2.201'],
#  'pointer moves': ['-2.201'],
#  'the thinkvantage': ['-2.201'],
#  'to s-video': ['-2.201'],
#  'issue between': ['-2.201'],
#  'unit kept': ['-2.201'],
#  'the honeymoon': ['-2.201'],
#  'one unless': ['-2.201'],
#  'worst purchases': ['-2.201'],
#  'tried removing': ['-2.201'],
#  "companion 3's": ['-2.201'],
#  'really unhappy': ['-2.201'],
#  'designed_NEG in': ['-2.201'],
#  'fan problem': ['-2.201'],
#  'back tomorrow': ['-2.201'],
#  "doesn't that": ['-2.201'],
#  'hate these': ['-2.201'],
#  'was polite': ['-2.201'],
#  'wait 10': ['-2.201'],
#  'scam .': ['-2.201'],
#  'keys was': ['-2.201'],
#  ', intermittent': ['-2.201'],
#  'a recall': ['-2.201'],
#  'support representative': ['-2.201'],
#  'sent_NEG the': ['-2.201'],
#  'boxed it': ['-2.201'],
#  'good_NEG either_NEG': ['-2.201'],
#  'expired )': ['-2.201'],
#  'just slow': ['-2.201'],
#  'beware --': ['-2.201'],
#  'after 45': ['-2.201'],
#  'keeps coming': ['-2.201'],
#  'complete garbage': ['-2.201'],
#  ': poor': ['-2.201'],
#  'warranty runs': ['-2.201'],
#  'bad connection': ['-2.201'],
#  'this n': ['-2.201'],
#  'been returned': ['-2.201'],
#  'my question_NEG': ['-2.201'],
#  'after hibernation': ['-2.201'],
#  'else_NEG from': ['-2.201'],
#  'three calls': ['-2.201'],
#  'to sent': ['-2.201'],
#  'they blamed': ['-2.201'],
#  'first sign': ['-2.201'],
#  'most useless': ['-2.201'],
#  'software twice': ['-2.201'],
#  'scan function': ['-2.201'],
#  'hired a': ['-2.201'],
#  'started crashing': ['-2.201'],
#  '9 times': ['-2.201'],
#  'a ping': ['-2.201'],
#  'a locked': ['-2.201'],
#  'valuable time': ['-2.201'],
#  'expensive paperweight': ['-2.201'],
#  'wrong battery': ['-2.201'],
#  'iomega tech': ['-2.201'],
#  'advise_NEG anyone_NEG': ['-2.201'],
#  'service again': ['-2.201'],
#  'bug with': ['-2.355'],
#  'horrible company': ['-2.355'],
#  'their answer': ['-2.355'],
#  'not deserve_NEG': ['-2.355'],
#  'total_NEG waste_NEG': ['-2.355'],
#  'was three': ['-2.355'],
#  'simply unacceptable': ['-2.355'],
#  'negative stars': ['-2.355'],
#  'support ever': ['-2.355'],
#  'charging me': ['-2.355'],
#  'a script_NEG': ['-2.355'],
#  'barely able': ['-2.355'],
#  'is inexcusable': ['-2.355'],
#  'weak that': ['-2.355'],
#  'work_NEG !!!': ['-2.355'],
#  'this crap': ['-2.355'],
#  'process again': ['-2.355'],
#  'case number': ['-2.355'],
#  'sad thing': ['-2.355'],
#  'horrible service': ['-2.355'],
#  'a 0': ['-2.355'],
#  'tried switching': ['-2.355'],
#  'only stay': ['-2.355'],
#  'back saying': ['-2.355'],
#  'is dangerous': ['-2.355'],
#  'be_NEG sent_NEG': ['-2.355'],
#  'huge mistake': ['-2.355'],
#  'device never': ['-2.355'],
#  'wasted ,': ['-2.355'],
#  'actual is': ['-2.355'],
#  'the webtv': ['-2.355'],
#  'spyder2 pro': ['-2.355'],
#  'negative experience': ['-2.355'],
#  'worked one': ['-2.355'],
#  'sony in': ['-2.355'],
#  'of error': ['-2.355'],
#  'is_NEG terrible_NEG': ['-2.355'],
#  'doorstop .': ['-2.355'],
#  'this useless': ['-2.355'],
#  'most poorly': ['-2.355'],
#  'i disappointed': ['-2.355'],
#  'bad performance': ['-2.355'],
#  'was flimsy': ['-2.355'],
#  'emails_NEG .': ['-2.355'],
#  'bootup ,': ['-2.355'],
#  '$250 to': ['-2.355'],
#  'disappointing experience': ['-2.355'],
#  'failure after': ['-2.355'],
#  "i'm unable": ['-2.355'],
#  'horrible battery': ['-2.355'],
#  'full_NEG refund_NEG': ['-2.355'],
#  'it broke_NEG': ['-2.355'],
#  'waste time': ['-2.355'],
#  'computer_NEG could_NEG': ['-2.355'],
#  'returning these': ['-2.355'],
#  'after 24': ['-2.355'],
#  'title states': ['-2.355'],
#  'of warranty_NEG': ['-2.355'],
#  'in concept': ['-2.355'],
#  'overheats ,': ['-2.355'],
#  'have spend': ['-2.355'],
#  'useless with': ['-2.355'],
#  'longer_NEG recognizes_NEG': ['-2.355'],
#  'issue will': ['-2.355'],
#  'rma and': ['-2.355'],
#  'script and': ['-2.355'],
#  "support i've": ['-2.355'],
#  'wont even_NEG': ['-2.355'],
#  'fixed_NEG the': ['-2.355'],
#  'fan blade': ['-2.355'],
#  'tried hooking': ['-2.355'],
#  'still overheats': ['-2.355'],
#  'a stable_NEG': ['-2.355'],
#  '6000l and': ['-2.355'],
#  'led would': ['-2.355'],
#  'by warranty_NEG': ['-2.355'],
#  'only plus': ['-2.355'],
#  'support does': ['-2.355'],
#  'or recommend_NEG': ['-2.355'],
#  'repaired the': ['-2.355'],
#  'even_NEG detect_NEG': ['-2.355'],
#  "battery didn't": ['-2.355'],
#  'to box': ['-2.355'],
#  'has cost': ['-2.355'],
#  'me pay': ['-2.355'],
#  "can't send_NEG": ['-2.355'],
#  "drive wouldn't": ['-2.355'],
#  'acknowledged that': ['-2.355'],
#  'customer has': ['-2.355'],
#  'the disappointment': ['-2.355'],
#  'the headaches_NEG': ['-2.355'],
#  'further research': ['-2.355'],
#  'or replace_NEG': ['-2.355'],
#  'compatible_NEG as': ['-2.355'],
#  'he sent': ['-2.355'],
#  'crashes my': ['-2.355'],
#  'its warranty': ['-2.355'],
#  '! avoid': ['-2.355'],
#  'started smoking': ['-2.355'],
#  'never buying_NEG': ['-2.355'],
#  'was unusable': ['-2.355'],
#  'hp computer_NEG': ['-2.355'],
#  'just wasted': ['-2.355'],
#  'call again': ['-2.355'],
#  'with india': ['-2.355'],
#  'every 20': ['-2.355'],
#  'offered no': ['-2.355'],
#  'linksys on': ['-2.355'],
#  'cable stopped': ['-2.355'],
#  "' technical": ['-2.355'],
#  'protection "': ['-2.355'],
#  ', troubleshooting': ['-2.355'],
#  'disappointed -': ['-2.355'],
#  'careful -': ['-2.355'],
#  'poorly executed': ['-2.355'],
#  'refund for': ['-2.355'],
#  'happened ?': ['-2.355'],
#  'grinding sound': ['-2.355'],
#  'router failed': ['-2.355'],
#  'was supposedly': ['-2.355'],
#  'nice try': ['-2.355'],
#  'this worthless': ['-2.355'],
#  'broke !': ['-2.355'],
#  'run_NEG anything_NEG': ['-2.355'],
#  'not track_NEG': ['-2.355'],
#  'not refund_NEG': ['-2.489'],
#  'net framework': ['-2.489'],
#  'complete junk': ['-2.489'],
#  'light would': ['-2.489'],
#  'responsibility_NEG for': ['-2.489'],
#  'failed "': ['-2.489'],
#  'this crappy': ['-2.489'],
#  'nuvi 370': ['-2.489'],
#  ': stay': ['-2.489'],
#  'trash can': ['-2.489'],
#  'explained my': ['-2.489'],
#  'crap !': ['-2.489'],
#  "won't recommend_NEG": ['-2.489'],
#  'hangs .': ['-2.489'],
#  'accessed_NEG .': ['-2.489'],
#  'as toshiba': ['-2.489'],
#  'been without': ['-2.489'],
#  'keep shopping': ['-2.489'],
#  'anybody_NEG .': ['-2.489'],
#  'beware !!!': ['-2.489'],
#  'we contacted': ['-2.489'],
#  'worked once': ['-2.489'],
#  'it overheated': ['-2.489'],
#  "it's broken": ['-2.489'],
#  'computer freezes': ['-2.489'],
#  'really frustrating': ['-2.489'],
#  'perhaps if': ['-2.489'],
#  '. exchanged': ['-2.489'],
#  'bad support': ['-2.489'],
#  'even_NEG start_NEG': ['-2.489'],
#  'this garbage': ['-2.489'],
#  "wasn't plugged_NEG": ['-2.489'],
#  'is toast': ['-2.489'],
#  'crap and': ['-2.489'],
#  'crashes the': ['-2.489'],
#  'absolutely horrible': ['-2.489'],
#  'horrible for': ['-2.489'],
#  'jammed .': ['-2.489'],
#  'incredibly frustrating': ['-2.489'],
#  'aa &': ['-2.489'],
#  'instructed to': ['-2.489'],
#  'never called_NEG': ['-2.489'],
#  'reconnected my': ['-2.489'],
#  'went unanswered': ['-2.489'],
#  'the defective_NEG': ['-2.489'],
#  'is abysmal': ['-2.489'],
#  'usb led': ['-2.489'],
#  'just bad': ['-2.489'],
#  'cardbus adaptor': ['-2.489'],
#  'buying_NEG from': ['-2.489'],
#  'problem occurred': ['-2.489'],
#  'lap it': ['-2.489'],
#  'hinge broke': ['-2.489'],
#  'caused .': ['-2.607'],
#  'rude .': ['-2.607'],
#  'cycling the': ['-2.607'],
#  'return_NEG shipping_NEG': ['-2.607'],
#  'and refused': ['-2.607'],
#  'totally disappointed': ['-2.607'],
#  'very sorry': ['-2.607'],
#  'very rude': ['-2.607'],
#  'longer_NEG under': ['-2.607'],
#  'shipping_NEG costs_NEG': ['-2.607'],
#  'the agent': ['-2.607'],
#  'kept disconnecting': ['-2.607'],
#  'recommend_NEG purchasing_NEG': ['-2.607'],
#  'worst purchase': ['-2.607'],
#  'just unlucky': ['-2.607'],
#  'defective battery': ['-2.607'],
#  'grinding noises': ['-2.607'],
#  'nothing they': ['-2.607'],
#  'stopped recognizing': ['-2.607'],
#  'help_NEG whatsoever_NEG': ['-2.607'],
#  'sir ,': ['-2.607'],
#  'neither one': ['-2.607'],
#  'totally worthless': ['-2.607'],
#  'waiting and': ['-2.607'],
#  'cursor will': ['-2.607'],
#  'i help': ['-2.607'],
#  'i/o errors': ['-2.607'],
#  'many flaws': ['-2.607'],
#  'bad cable': ['-2.607'],
#  'the blaster': ['-2.607'],
#  'customer "': ['-2.607'],
#  'died out': ['-2.607'],
#  'terrible -': ['-2.607'],
#  'drops connections': ['-2.607'],
#  'toshiba laptops_NEG': ['-2.607'],
#  'sony computer_NEG': ['-2.607'],
#  '- stay': ['-2.607'],
#  'are junk': ['-2.607'],
#  'poor wireless': ['-2.712'],
#  'wasted time': ['-2.712'],
#  'terrible experience': ['-2.712'],
#  'their warranty_NEG': ['-2.712'],
#  'work_NEG wirelessly_NEG': ['-2.712'],
#  'bad ...': ['-2.712'],
#  'not answer_NEG': ['-2.712'],
#  'seemed great': ['-2.712'],
#  'it killed': ['-2.712'],
#  'toshiba product_NEG': ['-2.712'],
#  'refund my': ['-2.712'],
#  'i uninstall': ['-2.712'],
#  'faulty and': ['-2.712'],
#  'would suddenly': ['-2.712'],
#  "won't install_NEG": ['-2.712'],
#  'pretty disappointed': ['-2.712'],
#  'good concept': ['-2.712'],
#  'only fix': ['-2.712'],
#  'instead they': ['-2.712'],
#  'better business': ['-2.712'],
#  'costs !': ['-2.807'],
#  'copy cruiser': ['-2.807'],
#  'execution .': ['-2.807'],
#  'blades broke': ['-2.807'],
#  'never recognized_NEG': ['-2.807'],
#  'then quit': ['-2.807'],
#  'just stops': ['-2.807'],
#  "amazon's return": ['-2.807'],
#  'very dissatisfied': ['-2.894'],
#  '! stay': ['-2.894'],
#  'joke !': ['-2.894'],
#  'defcon cl': ['-2.894'],
#  'any toshiba': ['-2.894'],
#  'bad service': ['-2.894'],
#  'things started': ['-2.894'],
#  'be_NEG purchasing_NEG': ['-2.894'],
#  'junk for': ['-2.894'],
#  'number_NEG for': ['-2.894'],
#  'again_NEG after': ['-2.894'],
#  'dead after': ['-2.894'],
#  'of trash': ['-2.894'],
#  'garbage !': ['-2.974'],
#  'speak english': ['-2.974'],
#  'became loose': ['-2.974'],
#  'problem started': ['-2.974'],
#  'crashed again': ['-2.974'],
#  'a worthless': ['-3.048'],
#  'worse is': ['-3.048'],
#  'supervisor ,': ['-3.048'],
#  'worked_NEG again_NEG': ['-3.117'],
#  '. horrible': ['-3.117'],
#  'problems began': ['-3.117'],
#  ', awful': ['-3.117'],
#  'the rma': ['-3.117'],
#  'worth_NEG your': ['-3.117'],
#  'avoid at': ['-3.117'],
#  'minutes then': ['-3.117'],
#  'poorly constructed': ['-3.243'],
#  'they refuse': ['-3.243'],
#  'utterly useless': ['-3.300'],
#  'so disappointed': ['-3.405'],
#  '0 stars': ['-3.454'],
#  '. contacted': ['-3.500'],
#  'worst product': ['-3.587'],
#  'extremely disappointed': ['-3.875'],
#  '. buyer': ['-4.301'],
#  'squealing': ['-2.584'],
#  're-stocking': ['-2.584'],
#  'miserable_NEG': ['-2.584'],
#  'warrenty_NEG': ['-2.584'],
#  'mbit/sec': ['-2.584'],
#  'inno': ['-2.584'],
#  'joy_NEGFIRST': ['-2.584'],
#  '3-com': ['-2.584'],
#  'locksmith': ['-2.584'],
#  'poorest': ['-2.584'],
#  'jiggled': ['-2.584'],
#  'successfully_NEGFIRST': ['-2.584'],
#  'peril': ['-2.584'],
#  'microhub': ['-2.584'],
#  'dane-elec': ['-2.584'],
#  'poloroid': ['-2.584'],
#  'yr_NEG': ['-2.584'],
#  'process_NEGFIRST': ['-2.584'],
#  'helping_NEGFIRST': ['-2.584'],
#  'unacceptable_NEG': ['-2.584'],
#  'condescending': ['-2.584'],
#  "lexmark's": ['-2.584'],
#  'bluescreens': ['-2.584'],
#  'denies': ['-2.584'],
#  'merchandise_NEG': ['-2.584'],
#  'manufactured_NEGFIRST': ['-2.584'],
#  'n3': ['-2.584'],
#  'liars': ['-2.584'],
#  'wah': ['-2.738'],
#  'neophyte_NEG': ['-2.738'],
#  "winxp's": ['-2.738'],
#  '310x': ['-2.738'],
#  'spyder2': ['-2.738'],
#  'jamcam': ['-2.738'],
#  'bait': ['-2.738'],
#  'zire72': ['-2.738'],
#  'battary': ['-2.738'],
#  'sparking': ['-2.738'],
#  'thermal_NEG': ['-2.738'],
#  'reimbursed_NEG': ['-2.738'],
#  'urc': ['-2.738'],
#  'cd-rs_NEG': ['-2.738'],
#  'telling_NEGFIRST': ['-2.738'],
#  '750g': ['-2.738'],
#  '700z': ['-2.872'],
#  'durabook': ['-2.872'],
#  'istanbul': ['-2.872'],
#  'n19': ['-2.872'],
#  '11a': ['-2.990'],
#  'rotten': ['-2.990'],
#  'fxa47': ['-3.190'],
#  'unreliability': ['-3.277'],
#  '“': ['-3.500'],
#  'refund_NEGFIRST': ['-3.683']}

# %%
def emotion_analyzer(text,emotion_dict):
#   text = customer review
#   emotion_dict = get_nrc_data
    #Set up the result dictionary
    emotions = {x for y in emotion_dict.values() for x in y}
    emotion_count = dict()
    for emotion in emotions:
        emotion_count[emotion] = 0

    #Analyze the text and normalize by total number of words
    total_words = len(text.split())
    for word in text.split():
        if emotion_dict.get(word):
            for emotion in emotion_dict.get(word):
                emotion_count[emotion] += 1/len(text.split())
    return emotion_count

# %%
emotion_analyzer()

# %%
#output list with name, brand, price, link and image
def output(ID):
