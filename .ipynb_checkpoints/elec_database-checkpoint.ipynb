# %%
import pandas as pd
import numpy as np
import time

start_time = time.time()
url = 'https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Electronics_v1_00.tsv.gz'
url_data = pd.read_table(url, sep='\t', nrows=200000, error_bad_lines=False)
print("--- %s seconds ---" % (time.time() - start_time))
#url_data = pd.read_table(url, nrows=100000)
# Out:
# b'Skipping line 9076: expected 15 fields, saw 22\nSkipping line 19256: expected 15 fields, saw 22\nSkipping line 24313: expected 15 fields, saw 22\nSkipping line 47211: expected 15 fields, saw 22\nSkipping line 54295: expected 15 fields, saw 22\nSkipping line 56641: expected 15 fields, saw 22\nSkipping line 63067: expected 15 fields, saw 22\n'
# b'Skipping line 93796: expected 15 fields, saw 22\n'
# b'Skipping line 132806: expected 15 fields, saw 22\nSkipping line 164631: expected 15 fields, saw 22\nSkipping line 167019: expected 15 fields, saw 22\nSkipping line 167212: expected 15 fields, saw 22\n'
# b'Skipping line 198103: expected 15 fields, saw 22\nSkipping line 199191: expected 15 fields, saw 22\n'
# --- 72.21122598648071 seconds ---

# %%
url_data.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1          US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2          US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3          US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4          US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
#
#                                        product_title product_category  \
# 0  yoomall 5M Antenna WIFI RP-SMA Female to Male ...      Electronics
# 1         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 2        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 3  LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 4     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
url_data.loc[13]['review_body']

# %%
url_product = url_data.set_index('product_title')

by_ptitle = url_product.groupby('product_title')['star_rating'].agg(['mean', 'count'])

#create weighted function
def weighted(df):
    df['weighted'] = (10*df['mean'])*(df['count'])
    return df

by_ptitle.sort_values(['count', 'mean'], ascending=False)

#'make keywords associated with major catagories'
# Out:
#                                                         mean  count
# product_title
# Panasonic ErgoFit In-Ear Earbud Headphone           4.417766   2274
# Bluetooth Speaker, DKnight Magicbox Ultra-Porta...  4.286079   1566
# AmazonBasics High-Speed HDMI Cable - 6.5 Feet (...  4.742940   1381
# AmazonBasics High Speed HDMI Cable                  4.720088    911
# 1byone Amplified HDTV Antenna, with Detachable ...  3.868298    858
# VideoSecu ML531BE TV Wall Mount for most 22"-55...  4.598456    777
# Omaker M4 Portable Speakers                         4.465177    761
# CABTE High speed HDMI 1.4 HDMI cable 10ft 1080p...  4.703947    760
# Belkin 6-Outlet Home and Office Power Strip Sur...  4.524221    578
# AmazonBasics Ultra Thin Indoor HDTV Antenna         3.973310    562
# MEElectronics Sport-Fi M6 Noise Isolating In-Ea...  3.647750    511
# Anker Classic Portable Wireless Bluetooth Speak...  4.473361    488
# Cheetah APTMM2B TV Wall Mount for 20-75" TVs up...  4.570833    480
# ...

# %%
by_ptitle.describe()
# Out:
#                mean         count
# count  35230.000000  35230.000000
# mean       4.018984      5.676980
# std        1.239650     26.633817
# min        1.000000      1.000000
# 25%        3.500000      1.000000
# 50%        4.500000      1.000000
# 75%        5.000000      3.000000
# max        5.000000   2274.000000

# %%
unique_id_list = pd.Series(list(url_data['product_id'].unique()))
# df = pd.DataFrame(unique_id_list, )
# for x in unique_id_list:

# %%
url_data.groupby('product_id').count()
# Out:
#             marketplace  customer_id  review_id  product_parent  \
# product_id
# 0511189877            8            8          8               8
# 0594296420            4            4          4               4
# 0594451647            1            1          1               1
# 059445204X            1            1          1               1
# 097185548X            1            1          1               1
# 0972683275           40           40         40              40
# 1400501776            2            2          2               2
# 1400532620            1            1          1               1
# 1400532655            5            5          5               5
# 140053271X           10           10         10              10
# 1400599997            1            1          1               1
# 1400699894           21           21         21              21
# 193493139X            2            2          2               2
# ...
